# %%
import pandas as pd

# %%
df = pd.read_excel('/users/karolkul/desktop/GPR2020-wykaz.xlsx')

# %%
df
# Out:
#    ZAŁĄCZNIK NR 1 DO OPISU PRZEMIOTU ZAMÓWIENIA - CZĘŚĆ 1 - WYKAZ ODCINKÓW POMIAROWYCH GPR 2020 - TEREN DZIAŁANIA REJONU DRÓG WOJEWÓDZKICH W CZARNKOWIE  \
# 0                          WOJEWÓDZTWO: WIELKOPOLSKIE
# 1                                                 NaN
# 2                                     Nr odc. pomiar.
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                   1
# 7                                               30050
# 8                                               30051
# 9                                               30052
# 10                                              30053
# 11                                              30055
# 12                                              30057
# 13                                              30058
# 14                                              30061
# ...
